# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/MSFT_1986-03-13_2025-02-04.csv')
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.059827  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.061963   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063032   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061429    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060361    47894400

# %%
df.shape
# Out:
# (9800, 7)

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  9800.000000  9800.000000  9800.000000  9800.000000  9800.000000
# mean     63.173728    63.812493    62.513818    63.187157    57.451679
# std      98.682750    99.575073    97.725918    98.697881    98.714771
# min       0.088542     0.092014     0.088542     0.090278     0.055554
# 25%       5.898438     5.976563     5.794922     5.880860     3.618860
# 50%      27.436250    27.770000    27.200001    27.490000    19.266710
# 75%      47.597813    48.145000    47.062500    47.592500    40.066001
# max     467.000000   468.350006   464.459991   467.559998   465.786438
#
#              Volume
# count  9.800000e+03
# mean   5.630897e+07
# std    3.812127e+07
# min    2.304000e+06
# 25%    3.141062e+07
# 50%    4.946235e+07
# 75%    7.027870e+07
# max    1.031789e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9800 non-null   object
#  1   Open       9800 non-null   float64
#  2   High       9800 non-null   float64
#  3   Low        9800 non-null   float64
#  4   Close      9800 non-null   float64
#  5   Adj Close  9800 non-null   float64
#  6   Volume     9800 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 536.1+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9800 non-null   datetime64[ns]
#  1   Open       9800 non-null   float64
#  2   High       9800 non-null   float64
#  3   Low        9800 non-null   float64
#  4   Close      9800 non-null   float64
#  5   Adj Close  9800 non-null   float64
#  6   Volume     9800 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 536.1 KB

# %%
df.sort_values('Date', inplace=True)

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# %%
df.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close      Volume  \
# 0 1986-03-13  0.088542  0.101563  0.088542  0.097222   0.059827  1031788800
# 1 1986-03-14  0.097222  0.102431  0.097222  0.100694   0.061963   308160000
# 2 1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063032   133171200
# 3 1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061429    67766400
# 4 1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060361    47894400
#
#    Year  Month  Day
# 0  1986      3   13
# 1  1986      3   14
# 2  1986      3   17
# 3  1986      3   18
# 4  1986      3   19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9800 non-null   datetime64[ns]
#  1   Open       9800 non-null   float64
#  2   High       9800 non-null   float64
#  3   Low        9800 non-null   float64
#  4   Close      9800 non-null   float64
#  5   Adj Close  9800 non-null   float64
#  6   Volume     9800 non-null   int64
#  7   Year       9800 non-null   int32
#  8   Month      9800 non-null   int32
#  9   Day        9800 non-null   int32
# dtypes: datetime64[ns](1), float64(5), int32(3), int64(1)
# memory usage: 650.9 KB

# %%
df = df.astype({'Open': 'float32', 'High': 'float32', 'Close':'float32','Low':'float32','Adj Close':'int32', 'Volume': 'int32'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9800 non-null   datetime64[ns]
#  1   Open       9800 non-null   float32
#  2   High       9800 non-null   float32
#  3   Low        9800 non-null   float32
#  4   Close      9800 non-null   float32
#  5   Adj Close  9800 non-null   int32
#  6   Volume     9800 non-null   int32
#  7   Year       9800 non-null   int32
#  8   Month      9800 non-null   int32
#  9   Day        9800 non-null   int32
# dtypes: datetime64[ns](1), float32(4), int32(5)
# memory usage: 421.2 KB

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.title('Correlation Heatmap of Dataset')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Dataset')

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr>0.9, annot=True)
plt.title('Correlation Heatmap of Dataset')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Dataset')

# %%
sns.lineplot(data=df, x='Year',y='Open', color='red')
# Out:
# <Axes: xlabel='Year', ylabel='Open'>

# %%
sns.lineplot(data=df, x='Year',y='Close', color='red')
# Out:
# <Axes: xlabel='Year', ylabel='Close'>

# %%
sns.lineplot(data=df, x='Year',y='High', color='red')
# Out:
# <Axes: xlabel='Year', ylabel='High'>

# %%
sns.lineplot(data=df, x='Year',y='Low', color='red')
# Out:
# <Axes: xlabel='Year', ylabel='Low'>

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.histplot(data=df, x='Open', bins = 30,kde=True)
plt.title('Distribution of Open')

plt.subplot(2,2,2)
sns.histplot(data=df, x='Close', bins = 30,kde=True)
plt.title('Distribution of Close')


plt.subplot(2,2,3)
sns.histplot(data=df, x='High', bins = 30,kde=True)
plt.title('Distribution of High')

plt.subplot(2,2,4)
sns.histplot(data=df, x='Low', bins = 30,kde=True)
plt.title('Distribution of Low')

plt.show()

# %%
sns.pairplot(df[['Open','Close','Low','High']])
plt.suptitle('Pair Plot of Stock Price of Metrics', y=1.02)
plt.show()
sns.set(style='whitegrid')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df[['Open','Close','Low','High']])
plt.title('Box plot of Stock price columns')
plt.show()
sns.set(style='whitegrid')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = df[['Close','High','Low','Adj Close']]
y = df['Open']

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
print('Shape of X Train', x_train.shape)
print('Shape of Y Train',y_train.shape)
print('Shape of X Test', x_test.shape)
print('Shape of Y Test', y_test.shape)
# Out:
# Shape of X Train (7840, 4)
# Shape of Y Train (7840,)
# Shape of X Test (1960, 4)
# Shape of Y Test (1960,)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=4)
x_train = pca.fit_transform(x_train)
x_test = pca.fit_transform(x_test)

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.fit_transform(x_test)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1,1))
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1))

# %%
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(r2_score(y_test, y_pred))
# Out:
# 0.9997957367511784

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential([
    Input(shape=(x_train_scaled.shape[1],)),
    Dense(128,activation='relu'),
    Dropout(0.2),
    Dense(64,activation='relu'),
    Dense(1, activation='linear')
])

model.compile(optimizer='adam',loss = 'mean_squared_error', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_42 (Dense)                │ (None, 128)            │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,961 (35.00 KB)
#  Trainable params: 8,961 (35.00 KB)
# ...

# %%
callback = EarlyStopping(
    monitor ='val_loss',
    patience = 20,
    min_delta = 0.0001,
    verbose=1,
    mode = 'auto',
    baseline=None
)
history = model.fit(x_train_scaled, y_train_scaled,validation_split=0.2, epochs=50, batch_size=32 )
# Out:
# Epoch 1/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2455 - mse: 0.2455 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 2/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 3/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 4/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 5/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 6/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 7/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 8/50
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 9/50
# ...

# %%
y_pred = model.predict(x_test_scaled)
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
print('R2 Score:', r2_score(y_test_scaled, y_pred))
print('MSE Score:', mean_squared_error(y_test_scaled, y_pred))
print('MAE Score:', mean_absolute_error(y_test_scaled, y_pred))
# Out:
# R2 Score: 0.9956745505332947
# MSE Score: 0.004161903169006109
# MAE Score: 0.039905596524477005

# %%
y_pred_scaled= model.predict(x_test_scaled)
y_pred_actual = scaler_y.inverse_transform(y_pred_scaled)
y_test_actual = scaler_y.inverse_transform(y_test_scaled)

print('R2 Score:', r2_score(y_test_actual, y_pred_actual))
print('MSE Score:', mean_squared_error(y_test_actual, y_pred_actual))
print('MAE Score:', mean_absolute_error(y_test_actual, y_pred_actual))
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# R2 Score: 0.9956745505332947
# MSE Score: 40.833412170410156
# MAE Score: 3.9527158737182617

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(y_test_actual, y_pred_actual, alpha=0.5)
plt.plot([y_test_actual.min(), y_test_actual.max()],
         [y_test_actual.min(), y_test_actual.max()], 'r--')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.grid(True)
plt.show()

# %%
plt.plot(history.history['loss'], color='red', label='loss')
plt.plot(history.history['val_loss'], color='black', label='val_loss')
plt.legend()
plt.grid('blackgrid')
plt.show()

# %%
plt.plot(history.history['mse'], color='red', label='MSE')
plt.plot(history.history['val_mse'], color='black', label='val_mse')
plt.legend()
plt.grid('blackgrid')
plt.show()
